# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

x = np.arange(-4,4.1,0.1)
pdfx = stats.norm.pdf(x)

fig, ax = plt.subplots()
ax.plot(x, pdfx, marker='o', linestyle='none')
ax.set(xlabel='x', ylabel='pdf')
# Out:
# [Text(0, 0.5, 'pdf'), Text(0.5, 0, 'x')]

# %%
sampx = stats.norm.rvs(size=500, loc=0, scale=1)

# an alternative is
# sampx = numpy.random.normal(size=500, loc=0, scale=1)

fig, ax = plt.subplots()
ax.plot(sampx, marker='o', linestyle='none')

# %%
fig, ax = plt.subplots()
ax.hist(sampx)
# Out:
# (array([  1.,   0.,   6.,  29.,  84., 116., 141.,  83.,  32.,   8.]),
#  array([-4.39416238, -3.68305474, -2.9719471 , -2.26083946, -1.54973183,
#         -0.83862419, -0.12751655,  0.58359109,  1.29469873,  2.00580637,
#          2.716914  ]),
#  <a list of 10 Patch objects>)

# %%
ksd = stats.gaussian_kde(sampx)

fig, ax = plt.subplots()
ax.plot(x, ksd(x))
ax.set(xlabel='x', ylabel='density')
# Out:
# [Text(0, 0.5, 'density'), Text(0.5, 0, 'x')]
